# %%
import pandas as pd
import datasense as ds
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('bitcoin.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %% [markdown]
# # -> Exploration of Time-Series Data on Daily, Monthly and Yearly basis

# %%
# Daily
ds.timeseries.analyze_timeseries(df,date_col='Date',target_col='Close',freq='D', window=7)
# Out:
# ## ⏳ Time-Series Analysis
# 📈 The rolling mean suggests an **increasing trend** over time.
# ✅ The series has **low/moderate volatility**.
# 🔍 **Decomposition Insights:**
# - **Trend** shows the long-term direction of the series.
# - **Seasonal** captures repeated patterns (e.g., daily, weekly, yearly).
# - **Residual** highlights irregular fluctuations not explained by trend/seasonality.
# 📏 The decomposition shows **weak or minimal seasonality**.
# ## 📝 Summary Report
# 1. 📈 The rolling mean suggests an **increasing trend** over time.
# 2. ✅ The series has **low/moderate volatility**.
# 3. - **Trend** shows the long-term direction of the series.
# 4. - **Seasonal** captures repeated patterns (e.g., daily, weekly, yearly).
# 5. - **Residual** highlights irregular fluctuations not explained by trend/seasonality.
# 6. 📏 The decomposition shows **weak or minimal seasonality**.

# %%
# Monthly
ds.timeseries.analyze_timeseries(df,date_col='Date',target_col='Close',freq='M', window=30)
# Out:
# ## ⏳ Time-Series Analysis
# 📈 The rolling mean suggests an **increasing trend** over time.
# ✅ The series has **low/moderate volatility**.
# 🔍 **Decomposition Insights:**
# - **Trend** shows the long-term direction of the series.
# - **Seasonal** captures repeated patterns (e.g., daily, weekly, yearly).
# - **Residual** highlights irregular fluctuations not explained by trend/seasonality.
# 📏 The decomposition shows **weak or minimal seasonality**.
# ## 📝 Summary Report
# 1. 📈 The rolling mean suggests an **increasing trend** over time.
# 2. ✅ The series has **low/moderate volatility**.
# 3. - **Trend** shows the long-term direction of the series.
# 4. - **Seasonal** captures repeated patterns (e.g., daily, weekly, yearly).
# 5. - **Residual** highlights irregular fluctuations not explained by trend/seasonality.
# 6. 📏 The decomposition shows **weak or minimal seasonality**.

# %%
#Yearly
ds.timeseries.analyze_timeseries(df,date_col='Date',target_col='Close',freq='Y', window=365)
# Out:
# ## ⏳ Time-Series Analysis
# ℹ️ Not enough data points to determine trend.
# ✅ The series has **low/moderate volatility**.
# 🔍 **Decomposition Insights:**
# - **Trend** shows the long-term direction of the series.
# - **Seasonal** captures repeated patterns (e.g., daily, weekly, yearly).
# - **Residual** highlights irregular fluctuations not explained by trend/seasonality.
# 📏 The decomposition shows **weak or minimal seasonality**.
# ## 📝 Summary Report
# 1. ℹ️ Not enough data points to determine trend.
# 2. ✅ The series has **low/moderate volatility**.
# 3. - **Trend** shows the long-term direction of the series.
# 4. - **Seasonal** captures repeated patterns (e.g., daily, weekly, yearly).
# 5. - **Residual** highlights irregular fluctuations not explained by trend/seasonality.
# 6. 📏 The decomposition shows **weak or minimal seasonality**.
